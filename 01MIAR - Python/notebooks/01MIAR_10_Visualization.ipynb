# %% [markdown]
# <img src="img/viu_logo.png" width="200">
#
# ## 01MIAR - Representación Gráfica
#
# ![logo](img/python_logo.png)
#
# *Ivan Fuertes*
#
# *Benjamin Arroquia Cuadros*

# %% [markdown]
# ## Examen final
# - 01MIAR_Exam_Demo.ipynb
# - Hora de 20h a 22h
# - Mismo examen en ambos grupos
# - Ocho preguntas en Jupyter notebook
# - Sólo se puede usar Jupyter Notebook o Jupyter Lab
# - No está permitido ningún asistente de IA
# - Sí está permitido hacer uso de buscador
# - Importante: Configurar SMOWL antes del examen
#     - Conectarse 10 minutos antes al examen y probar SMOWL
#     - Problemas técnicos contactar con SMOWL
#
# #### Representacion grafica
# - matplotlib basico (plot, legend, decoradores y anotaciones, grabar)
# - dibujo con pandas (tipos de graficos)
# - intro a seaborn https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# #### Referencias
# - https://plotdb.com/
# - https://d3js.org/
# - https://plot.ly/python/
# - https://bokeh.org/
# - https://shiny.rstudio.com/gallery/
# - https://www.tableau.com/es-es
# - https://powerbi.microsoft.com/es-mx/
#
# #### Auto EDA
# - https://pypi.org/project/pandas-profiling/
# - https://pypi.org/project/dtale/

# %% [markdown]
# # matplotlib
# - Librería estándar de representación gráfica
# - Low level: fácil de usar, difícil de dominar
#  - Control
# - Gráficos y diagramas

# %% [markdown]
# ### Elementos de visualización
# - Gráfico. Tipo de representación dentro de una subfigura o figura. Existen gran cantidad de tipos de gráficos: barras, líneas, tarta...
# - Subfigura. Representación dentro de una figura.
# - Figura. Marco donde se representan de manera conjunta una visualización. Se caracterizan por tener un título general y suele tener una descripción así como una fuente o referencia

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# - 'plot(data)' para crear un gráfico con 'data'
# - 'show()' para mostrarlo

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# magic command para visualizar gráficos en jupyter en modo no interactivo
# %matplotlib inline

# %%
data = np.random.randint(100,size=(3,3))
display(data)
plt.plot(data) # creación del gráfico
plt.show() # comando que muestra los gráficos creados hasta el momento
# Out:
# array([[39, 14, 49],
#        [50, 60, 37],
#        [ 0, 27, 47]])

# %%
# activar modo interactivo
# %matplotlib notebook
# plt.ioff() # evitar que se sobreescriban los gráficos
# %matplotlib inline
# para tener ventanas e interactivo
# %matplotlib tk

# %%
# Se pueden especificar x e y por separado
x_data = np.arange(75, 100) # dimensiones! Crea una lista desde el 75 al 99
y_data = np.random.randint(80,size=(25)) # crea una lista de numeros random de 0 al 80 total n=25-1

print(x_data,y_data)

if x_data.size == y_data.size:
    plt.plot(x_data,y_data)
    plt.show()      
else:
    print(f"{x_data.size} no tienen las mismas dimensiones {y_data.size}")
# Out:
# [75 76 77 78 79 80 81 82 83 84 85 86 87 88 89 90 91 92 93 94 95 96 97 98
#  99] [51 33  3 63 16 21 46 54 30 50 26 53 66  4 65 47 24 61 47 15 47 51 35  9
#  21]

# %% [markdown]
# ## figure, axes
# - Figure: objeto en el que residen todos los gráficos (uno o múltiples)
# - Axes: cada uno de los subplots (o gráficos) dentro de Figure

# %%
plt.subplot_mosaic('aabc\naadd') # crea varios subplots, en la primera genera 4 axis pero con aa fusiona 2 axis
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  {'a': <AxesSubplot:label='a'>,
#   'b': <AxesSubplot:label='b'>,
#   'c': <AxesSubplot:label='c'>,
#   'd': <AxesSubplot:label='d'>})

# %%
# fig, axes = plt.subplots(1,2) # crea una ndarray de 1x2 axes (o subplots). Cuando vamos a hacer mas de una grafica en la figura
fig, axes = plt.subplots(1,2, figsize=(6, 4)) # figsize=(6, 4) es el tamaño en x e y en toda la figura
print(type(axes))
print(axes)
# Out:
# <class 'numpy.ndarray'>
# [<AxesSubplot:> <AxesSubplot:>]

# %%
# Generar los datos
x_data1 = np.arange(0,10)
x_data2 = np.arange(-10,0)
y_data1 = np.random.randint(100,size=(10))
y_data2 = np.random.randint(1000,size=(10))

# %%
# Crear la figura y los subplots
fig, axes = plt.subplots(1,2)
# , sharey=True
# preparar cada subplot
axes[0].plot(x_data1,y_data1) # indico la grafica en la posicion 1
axes[1].plot(x_data2,y_data2) # la grafica en la posicion 2
# axes[1].sharey(axes[0]) # comparte las escalas para poder comparar los graficos

# mostrar ambos axes
plt.show() # Recomendable usar plt y no fig.show()

# %%
# crear un nuevo eje con la x compartida
fig, ax = plt.subplots(1, 1, figsize=(2, 4))
x = np.arange(12)
ax.plot(x, "r")

ax2 = ax.twinx() #une dos graficas con diferentes escalas o medidas en una sola
ax2.plot(x ** 2, "g") # = x², g= green
plt.show()

# %%
# Crear la figura y los subplots
fig, axes = plt.subplots(1,2)
# preparar cada subplot agregando data
axes[0].plot(x_data1,y_data1)
axes[1].plot(x_data2,y_data2)

# tanto axes como fig pueden configurarse a través de funciones
axes[0].set_ylim([0,1000]) # modifico limites 
axes[0].set_xlim([-1,12])

axes[0].set_xlabel("Years") # modifico nombres de los ejes
axes[0].set_ylabel("Dollars")

axes[1].set_ylim([0,1000]) 
axes[1].set_xlim([-11,1])

plt.show()

# %% [markdown]
# ### Más métodos
# - Documentación general de la [API](https://matplotlib.org/stable/api/axes_api.html)

# %% [markdown]
# # .plot()
#
# Múltiples parámetros
#
# ```python
# plt.plot(x, y, style, label, linewidth=1, alpha=1)
# ```
#
# - 'style': cadena de texto con formato (color, tipo...) \[color\]\[marker\]\[line\]
# - 'label': referencia para leyenda
# - 'linewidth': brocha
# - 'alpha': transparencia
#
# Otros: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
y_data = np.random.randint(100,size=(10))
x_data = np.arange(10)
fig, axis = plt.subplots(1,1)
axis.plot(x_data,y_data,'g*--',label='dollars',linewidth=1,alpha=0.5) # creación del gráfico, color green y lineas discontinuas -- con *, label = nombre de la grafica, alpha= opacidad
axis.plot(x_data,y_data*-4,'r*--',label='euros',linewidth=1,alpha=0.5) # creación del gráfico
axis.legend(loc='upper left') # representar la leyenda
plt.show()

# %% [markdown]
# | Color | Descripción |
# |:------|:------------|
# | b | blue |
# | g | green |
# | r | red |
# | c | cyan |
# | m | magenta |
# | y | yellow |
# | k | black |
# | w | white |
#
# | Marcador | Descripción |
# |:------|:------------|
# | . | point marker |
# | , | pixel marker |
# | o | circle marker |
# | v | triangle_down marker |
# | ^ | triangle_up marker |
# | < | triangle_left marker |
# | > | triangle_right marker |
# | 1 | tri_down marker |
# | 2 | tri_up marker |
# | 3 | tri_left marker |
# | 4 | tri_right marker |
# | s | square marker |
# | p | pentagon marker |
# | * | star marker |
# | h | hexagon1 marker |
# | H | hexagon2 marker |
# | + | plus marker |
# | x | x marker |
# | D | diamond marker |
# | d | thin_diamond marker |
# | | | vline marker |
# | _ | hline marker |
#
# | Línea | Descripción |
# |:------|:------------|
# | - | solid line style |
# | -- | dashed line style |
# | -. | dash-dot line style |
# | : | dotted line style |

# %% [markdown]
# ### Representar más de un gráfico en una subfigura

# %%
x_data = np.arange(10)
fig,axis = plt.subplots(1,1)
axis.plot(x_data,np.random.randint(100,size=(10)),'go-',label='green',linewidth=1,alpha=0.2) # creación del gráfico
axis.plot(x_data,np.random.randint(100,size=(10)),'bx-.',label='blue',linewidth=1, alpha=0.6) # creación del gráfico
axis.plot(x_data,np.random.randint(50,80,size=(10)),'rh-.',label='red',linewidth=1, alpha=0.4) # creación del gráfico
axis.legend(loc='best') # posicion del label
plt.grid() # muestra grilla
plt.show()

# %% [markdown]
# ## Decoradores
#
# Cambian el aspecto general de la figura
# ```python
# axes.set_xticks(<lista>) #etiquetas del eje
# axes.set_title(‘titulo’) #titulo
# axes.set_ylabel(‘label’)
# axes.set_frame_on(bool)
# ```
# [Más métodos](https://matplotlib.org/stable/api/axes_api.html)

# %% [markdown]
# # Anotaciones
#
# Formas de añadir información sobre el gráfico
#
# ```python
# axes.text(x,y,’texto’)
# axes.annotate(texto, xy, xytext, xycoords, arrowprops)
# ```
#
# [Más métodos](https://matplotlib.org/stable/tutorials/text/annotations.html)

# %%
y_data = np.random.randint(100, size=(10)) # Cuidado con las dimensiones absolutas
x_data = np.arange(10)

# %%
x_data[8],y_data[8]
# Out:
# (8, 68)

# %%
fig,axis = plt.subplots(1,1)
axis.plot(x_data,y_data)
axis.text(x_data[3],y_data[3],'Low income') # coordenadas igual a los datos
axis.annotate('Low Income', xy=(x_data[8],y_data[8]), xytext=(4, 10), arrowprops = dict(facecolor='red', shrink=0.5)) # anotación completa
plt.show()

# %%
# Estilo general de la figura
plt.style.use('ggplot')

# %% [markdown]
# # Tipos de gráficos
#
# Ejemplos disponibles como referencia
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
# Horizontal bar
fig, ax = plt.subplots()
# Example data
people = ('PhD', 'MSc', 'BSc', 'N/A')
y_pos = np.arange(len(people))
percentage = [5,45,25,25]

ax.barh(y_pos, percentage, align='center',
        color='green', edgecolor='red')
ax.set_xlabel('Percentage of workforce')
ax.set_title('Level of education in the company')
plt.show()

# %% [markdown]
# - Cuidado con lo que se quiere representar!
# - Si el dato es categórico hay que representralo bien

# %%
# Horizontal bar
fig, ax = plt.subplots()
# Example data
people = ('PhD', 'MSc', 'BSc', 'N/A')
y_pos = np.arange(len(people))
percentage = [5,45,25,25]

ax.barh(y_pos, percentage, align='center',
        color='green', edgecolor='red')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Percentage of workforce')
ax.set_title('Level of education in the company')
plt.show()

# %%
ls_count = (284487, 244560, 208493, 196764)
cities = ('Madrid', 'Barcelona', 'Sevilla', 'Valencia')
data = np.array(ls_count)/1000
y_pos = np.arange(data.size)

width = 0.35       # the width of the bars
opacity = 0.7

fig, ax = plt.subplots()
rects1 = ax.barh(y_pos, data, width, alpha=opacity)

rects1[3].set_color('#ff9757')
rects1[2].set_color('#ffcb59')
rects1[1].set_color('#d6ee39')
rects1[0].set_color('#6ade30')

ax.set_yticks(y_pos)
ax.set_yticklabels(cities)

# add some text for labels, title and axes ticks
ax.set_ylabel('Ciudades')
ax.set_xlabel('Km de carril bici')

ax.legend((rects1[0], rects1[1], rects1[2], rects1[3]), cities)

plt.show()

# %%
# stack plot
x = [2008, 2009, 2010, 2011, 2012]
iOS = [35, 25, 20, 17, 18]
Android = [0, 15, 35, 45, 60]
WindowsPhone = [1, 3, 5, 5, 2]
Others = [64,57,40,33,20]

y = np.vstack([iOS, Android, WindowsPhone,Others])
print(y)

labels = ["iOS ", "Android", "WindowsPhone", "Others"]

fig, ax = plt.subplots()
# ax.stackplot(x, iOS, Android, WindowsPhone, Others,labels=labels)
ax.stackplot(x, y, labels=labels)# representa una cuota de mercado x años y y hasta el 100
ax.set_xticks(x)
ax.legend(loc='upper left')
plt.show()
# Out:
# [[35 25 20 17 18]
#  [ 0 15 35 45 60]
#  [ 1  3  5  5  2]
#  [64 57 40 33 20]]

# %%
pd.DataFrame(y.T, columns=labels)
# Out:
#    iOS   Android  WindowsPhone  Others
# 0    35        0             1      64
# 1    25       15             3      57
# 2    20       35             5      40
# 3    17       45             5      33
# 4    18       60             2      20

# %%
# Scatter plot
from numpy.random import rand

fig, ax = plt.subplots()
n = 700
for color in ['red', 'green', 'blue']:
    x, y = rand(2, n)
    scale = 25.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
plt.show()

# %%
# Crear figuras y scatter plot
np.random.seed(44)
n = 1000
x = [np.random.uniform(0, 1) for i in range(0, n)]
y = [np.random.uniform(0, 1) for i in range(0, n)]
fig, ax = plt.subplots(figsize=(5, 5))
scat1 = plt.plot(x, y, 'o', color='black', markersize=2)
circle1 = plt.Circle((0, 0), 1, color='r')
ax.add_artist(circle1)
ax.add_artist(circle1)
plt.show()

# %% [markdown]
# ## Grabar a archivo
# ```python
# figure.savefig(<filename>,dpi=None, facecolor=’w’, edgecolor=’w’, format=None, bbox_inches=None)
# ```

# %%
# guardar la figura (puede ser múltiples gráficos)
import os
ruta = os.path.join("res", "o_figure.png")

fig.savefig(ruta, format='png') # varios formatos aceptados (‘pdf’,’ png’, ‘svg’, ‘eps’...), dpi puntos por pulgada dots per inch

# %% [markdown]
# # Representación gráfica en pandas
#
# - pandas ofrece interfaz para dibujar Series y DataFrame
# - Usa matplotlib internamente
# - Fácil de usar

# %%
rand_matrix = np.random.randint(100,size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('AXC'))
frame.plot()
plt.show() # aún es necesario llamar a show() para mostrar los gráficos

display(frame) # datos en eje x, eje y, leyenda, series?
# Out:
#     A   X   C
# 0  90  17   8
# 1  62  31  93
# 2  38  54  32
# 3  32  82  53
# 4  36  10  72
# 5  26  19  32
# 6  94   6  16
# 7  22  68  82
# 8  94  11  19
# 9  17  40   0

# %% [markdown]
# # frame.plot()
#
# ```python
# frame.plot(x,y,label=<Series>,ax,style,kind,xticks,yticks,title,subplots)
# ```
#
# - (solo para Series) label: referencia para la leyenda
# - ax: subfigura en la que dibujar los datos
# - style: estilo de la línea
# - kind: tipo de gráfico ('bar’, ‘pie’, ‘hist’, ‘area’ ‘line’, ‘barh’, ‘density’, ‘kde’).
# - xticks y yticks: valores en los ejes X e Y
# - title: string como título
# - (solo para DataFrame) subplots: bool si se desean subfiguras separadas para cada columna.
# - (solo para DataFrame) 'x' e 'y' se pueden utilizar para seleccionar columnas para cada eje
#
# [Lista completa](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html) de argumentos

# %%
ax
# Out:
# <AxesSubplot:>

# %%
rand_matrix = np.random.randint(100, size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('ABC'))
ax = frame.plot(style=['r-','g-','b-'], xticks=range(-2,12), 
           title='Random lines', subplots=True)
ax[1].set_title("a")
plt.show()
display(frame)
# Out:
#     A   B   C
# 0  90  17   8
# 1  62  31  93
# 2  38  54  32
# 3  32  82  53
# 4  36  10  72
# 5  26  19  32
# 6  94   6  16
# 7  22  68  82
# 8  94  11  19
# 9  17  40   0

# %%
# combinar pandas plot con matplotlib
rand_matrix = np.random.randint(100, size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('ABC'))

fig, axis = plt.subplots(3,1)
ax = frame.plot(style=['r-','g-','b-'], xticks=range(-2,12), title='Random lines', subplots=True, ax=axis)

ax[0].legend(loc='upper left')

plt.show()

# %%
# Gráfico de barras
frame.plot(kind='bar', title='Random lines')
plt.show()

# %%
# Gráfico de área
frame.plot(kind='area', xticks=range(-2,12), title='Random lines')
plt.show()

# %%
# Histogramas
frame.hist()
plt.show()

# %%
# Gráfico de pastel
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97], 
                   'radius': [2439.7, 6051.8, 6378.1]}, 
                  index=['Mercury', 'Venus', 'Earth'])
display(df)
df.plot(y='radius', kind='pie', title='Planets') # y variable a usar
plt.show()
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
# Gráfico de pastel
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97], 
                   'radius': [2439.7, 6051.8, 6378.1]}, 
                  index=['Mercury', 'Venus', 'Earth'])
display(df)
df.plot(y='radius', kind='bar', title='Planets') # y variable a usar
plt.show()
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %% [markdown]
# # Seaborn
#
# - Abstracción de matplotlib
# - Facilidad de uso y personalización
# - Excelente para exploración y visualización de relaciones entre variables

# %% [markdown]
# Viene con varios datasets predefinidos
# https://github.com/mwaskom/seaborn-data
#
# Documentación [oficial](https://seaborn.pydata.org/api.html)

# %%
import seaborn as sns

# %%
# Load data
flights_data = sns.load_dataset("flights")
# Construct plot
sns.swarmplot(x="month", y="passengers", data=flights_data)
# Show plot
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Compatible con pandas

# %%
# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 46        22.23  5.00    Male     No  Sun  Dinner     2
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 38        18.69  2.31    Male     No  Sat  Dinner     3
# 18        16.97  3.50  Female     No  Sun  Dinner     3
# 1         10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Construct plot representacion mas detallada, propina por dia
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Load in data
tips = pd.read_csv("./data/tips.csv")
tips.sample(5)
# Out:
#      total_bill   tip   sex smoker   day    time  size
# 159       16.49  2.00  Male     No   Sun  Dinner     4
# 63        18.29  3.76  Male    Yes   Sat  Dinner     4
# 237       32.83  1.17  Male    Yes   Sat  Dinner     2
# 90        28.97  3.00  Male    Yes   Fri  Dinner     2
# 193       15.48  2.02  Male    Yes  Thur   Lunch     2

# %%
ax = sns.barplot(x='sex', y='total_bill', hue='time', data=tips) # palette para color (negro desviacion). Hue parametro estrella, permikte poner una variable mas para poder comparar los datos, 
plt.show()

# %%
# Boxplot (cuartiles) Para analisis de datos permite ver si hay outlayers
ax = sns.boxplot(x='day', y='tip', data=tips)
# ax = sns.boxplot(x=tips['day'], y=tips.tip)
plt.show()

# %% [markdown]
# ￼## Relaciones entre variables
#
# ```python
# sns.relplot()
# ```

# %%
# tips = sns.load_dataset("tips")
path = 'https://github.com/mwaskom/seaborn-data/blob/master/tips.csv'

tips = pd.read_csv(os.path.join('data', 'tips.csv'))
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 42        13.94  3.06    Male     No   Sun  Dinner     2
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 91        22.49  3.50    Male     No   Fri  Dinner     2

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tips, kind='scatter') #hue da la coloracion de los puntos

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tips, kind='line')

# %%
# representar la media y la variación de una variable en función de otra
# data = sns.load_dataset('flights')
sns.relplot(x="year", y="passengers", kind="line", data=data)
# Out:
# /home/guevara/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:882: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   val in data
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [71], in <cell line: 3>()
#       1 # representar la media y la variación de una variable en función de otra
#       2 # data = sns.load_dataset('flights')
# ----> 3 sns.relplot(x="year", y="passengers", kind="line", data=data)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:947, in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     944     kwargs.pop("ax")
#     946 # Use the full dataset to map the semantics
# --> 947 p = plotter(
#     948     data=data,
#     949     variables=plotter.get_semantics(locals()),
#     950     legend=legend,
#     951 )
#     952 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     953 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:367, in _LinePlotter.__init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     353 def __init__(
#     354     self, *,
#     355     data=None, variables={},
#    (...)
#     361     # the kind of plot to draw, but for the time being we need to set
#     362     # this information so the SizeMapping can use it
#     363     self._default_size_range = (
#     364         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     365     )
# --> 367     super().__init__(data=data, variables=variables)
#     369     self.estimator = estimator
#     370     self.ci = ci
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `year` for parameter `x`

# %%
# fig, ax = plt.subplots()
# relacionar hasta 4 variables automáticamente
ax = sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="sex", height=4, # se uede hacer un subplot añadiendo al variable col
            kind="scatter",data=tips); #kind ('line','scatter'...)
# ax[0].legend()
# ax.set_size(1, 2)
plt.show()

# %% [markdown]
# ## Distribución de un dataset

# %%
# histograma y density plot
# kde = gaussian kernel density estimate, linea de densidad
# bins = tamaño de los contenedores
# rug = densidad de los datos
sns.displot(tips['tip'], kde=True, bins=30, rug=True) #kde saca la curva caracteristica
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Distribución bi-variable
sns.jointplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# Distribución bi-variable
sns.jointplot(x='total_bill', y='tip', hue='day', data=tips) # sirve para ver si se acumula mas en una parte antes que en otra, si se acumula mas en una semana, etc. Grafica de distribucion
plt.show()

# %%
iris["variety"].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
# Density plot bi-variable
# iris = sns.load_dataset('iris')
iris = pd.read_csv(os.path.join('data', 'iris.csv'))
display(iris.head(5))
display(iris["variety"].unique())
sns.jointplot(x='petal.length', y='petal.width', kind="kde", data=iris)
plt.show()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
# Relación de cada pareja
sns.pairplot(iris)
plt.show()

# %%
# Relación de cada pareja
sns.pairplot(iris, hue="variety")
plt.show()

# %%
# scatter de clases, coloreando segun clase en matplotlib

# preparacion de los datos
data = []
colors = ["red", "green", "blue"]
groups = ["Setosa", "Versicolor", "Virginica"]
columns = ["petal.length", "petal.width"]
for i in groups:
    # busqueda por clase definida
    data.append(iris[iris["variety"] == i][columns].values)


#creacion de la grafica
fig = plt.figure()
ax = fig.add_subplot()
for count, d in enumerate(data):
    # separar las variables del grafico
    x, y = d[:,0], d[:,1]
    ax.scatter(x, y, alpha = 0.4, c = colors[count -1], edgecolors = 'none', s = 30, label = groups[count - 1])
#etiquetas
ax.set_xlabel(columns[0])
ax.set_ylabel(columns[1])
plt.legend(loc='best')
plt.title('Matplot scatter plot')
plt.show()

# %% [markdown]
# ## Visualización de correlaciones
#
# - Regresión lineal con variables
# - Correlaciones numéricas

# %%
#correlación entre cuenta total y propina, recta regresion e intervalo de confianza
sns.regplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
#correlación con valores categóricos (variable discreta, variable debe ser numérica/continua) not a good idea
sns.regplot(x="size", y="tip", data=tips) # recta de regrecion 
plt.show()

# %%
# regresión con polinomios de más grados
sns.regplot(x="petal.length", y="sepal.width", data=iris, order=2) # ord 2 suavizada 
plt.show()

# %%
# Correlaciones con varias variables
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, col='time')
plt.show()

# %% [markdown]
# # Ejercicios
#
# - Representación gráfica con matplotlib y seaborn

# %% [markdown]
# ## matplotlib

# %% [markdown]
# - crear una lista de años de 2000 a 2020 (eje x)
# - generar datos aleatorios para el eje y (hacerlo 4 veces distintas: y0, y1, y2 e y3)
# - Representar las 4 secuencias de datos aleatorios en una sola figura utilizando matplotlib

# %% [markdown]
# - Añade una leyenda para poder identificar cada secuencia en el gráfico
# - Nombra las secuencias de la siguiente forma: "Hawaii", "San Marino", "Islas Feroe", "Guayana"

# %% [markdown]
# - Representar los mismos datos en 4 subfiguras (axes) distintas, parte de la misma figura

# %% [markdown]
# - Añade la siguiente info:
#   - Título: "Datos aleatorios"
#   - Leyenda
#   - Nombre del eje x: "Año"
#   - Nombre del eje y: "GDP"

# %% [markdown]
# - Añade al menos una anotación (texto y flecha) a uno de los gráficos

# %% [markdown]
# ## Seaborn

# %% [markdown]
# - Carga los datos de un dataset de seaborn (distinto a 'tips', 'iris' o 'flights') https://github.com/mwaskom/seaborn-data
#  - Si para alguno de los ejercicios no encuentras ejemplos en el dataset, busca otro para completarlo
#  - Recuerda utilizar la versión 'Raw' si se utiliza la URL en el método read_csv

# %% [markdown]
# - Representa visualmente la relación de cada pareja de atributos (variables)

# %% [markdown]
# - Escoge una pareja (ambos valores contínuos y numéricos) y demuestra su correlación

# %% [markdown]
# - Representa los valores de dos variables (x e y, numéricas) en base a otra variable (categórica)

# %% [markdown]
# - Crea los gráficos que demuestren lo siguiente en el dataset seleccionado:
#   - La distribución de valores (media, distribución, outliers) de una variable numérica contínua
#   - Compara la distribución de esa variable con otra (contínua y numérica) para representar cuantitativamente la densidad de elementos por valor en ambas variables
#   - Muestra un ejemplo en el dataset de una variable a la que un modelo de regresión lineal de orden > 1 sea más ajustado que uno de orden == 1
